# %% [markdown]
# <a href="https://colab.research.google.com/github/mati1yas/Machine-Learning-Track/blob/main/MLT_onboarding_Tasks_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Necessary Libraries

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #Pandas

# %% [markdown]
# ## Task1. download the movie dataset
#     ✅ I have dowloaded the dataset

# %% [markdown]
# ## Task2 . Parse the csv file into dataframe .

# %%
movie_df=pd.read_csv('imdb_top_1000.csv')     # read the csv file and convert it into data frame

# %%
# show the first some datas
movie_df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %% [markdown]
# ## Task3 . Answer the following questions

# %% [markdown]
# ### Question1 . what are the column names in the dataset .

# %%
data_column_names=movie_df.columns

# %%
data_column_names
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %% [markdown]
# ### Question 2. What is the average rating of the movies?

# %%
movie_rating_values=movie_df['IMDB_Rating']   # take all rating values of all movies from the dataframe 

average_rating=movie_rating_values.mean()     # calculated mean of the rating values 

average_rating
# Out:
# 7.949299999999999

# %% [markdown]
# ### Question 3. How many unique genres are there?

# %%
unique_movie_genres= movie_df['Genre'].nunique()
unique_movie_genres
# Out:
# 202

# %% [markdown]
# ## Task 4 .Save your answer as CSV

# %%
answers={
    "ans1":data_column_names,
    "ans2":average_rating,
    "ans3":unique_movie_genres
}   # formatted my answer in key value format 

answers_df=pd.DataFrame( answers )  # converted the json into dataframe 

answers_df.to_csv('answers_formatted.csv',index=False)

answers_df
# Out:
#              ans1    ans2  ans3
# 0     Poster_Link  7.9493   202
# 1    Series_Title  7.9493   202
# 2   Released_Year  7.9493   202
# 3     Certificate  7.9493   202
# 4         Runtime  7.9493   202
# 5           Genre  7.9493   202
# 6     IMDB_Rating  7.9493   202
# 7        Overview  7.9493   202
# 8      Meta_score  7.9493   202
# 9        Director  7.9493   202
# 10          Star1  7.9493   202
# 11          Star2  7.9493   202
# 12          Star3  7.9493   202
# 13          Star4  7.9493   202
# 14    No_of_Votes  7.9493   202
# 15          Gross  7.9493   202

# %% [markdown]
# # Data Visualization / Plotting

# %% [markdown]
# ## Task 1 . Plot a histogram of the genre distribution of the movies. How many movies from each genre are there in this list.

# %%
# get all generas from the dataset 
genres=movie_df['Genre']    
   
# count unique genres of the dataset 
unique_genres = genres.value_counts()

# %%
# set figure size 
plt.figure(figsize=(20,10)) 

# plot histogram 
plt.hist(genres,bins=len(genres.unique()), width=0.9)

# set x and y label 
plt.ylabel('Number of Movies ',fontsize=22)
plt.xlabel('Genres ',fontsize=22)

# set title for the plot 
plt.title("Movie To Genre Distribution: Histogram ",fontsize=30)
plt.xticks(rotation=45,ha= 'right')

plt.show()

# %%
# extracted data to put on x-axis and y-axis
x_axis_datas= unique_genres.index   
y_axis_datas=unique_genres.values   

plt.figure(figsize=(15,5))

#plot bar chart 
plt.bar(x_axis_datas,y_axis_datas)

# set x-axis and y-axis labels 
plt.ylabel('Number of Movies ' , fontsize=22)
plt.xlabel('Genres ',fontsize=22)
plt.title('Movie to Genre Distribution: Bar Chart ',fontsize=30)
plt.xticks(rotation=45)


plt.show()

# %% [markdown]
# ## Task 2 . Plot a scatterplot in this dataset for the number of movies vs year (Each year, how many movies made to this top 1000 list?)

# %%
# extract movies with their release year and count them 

movie_year=movie_df['Released_Year'].value_counts()

# sort movies based on index which is year of release
movie_year=movie_year.sort_index(ascending=True)


plt.figure(figsize=(20,10))  

# set label to the plot 
plt.ylabel('Number of Movies',fontsize=22)
plt.xlabel('Year of Release',fontsize=22)
plt.title("Number of Movies Released Each Year : Scatter Plot",fontsize=30)

# plot scatter diagram 
plt.scatter(movie_year.index,movie_year.values)
plt.xticks(rotation=45,ha= 'right')
plt.tight_layout()


plt.show()
